# %% [markdown]
# Dieses Notebook analysiert Produktpreise von **Hofer**, **Billa** und **Spar** – drei bekannten Supermärkten in Österreich.
# Die Daten stammen aus einer **MongoDB-Datenbank** und wurden zuvor automatisiert per Web Scraping gesammelt.

# %% [markdown]
# Wir stellen die Verbindung zur MongoDB her und laden alle Produktinformationen in ein `pandas` DataFrame.
# Damit arbeiten wir weiter in der Analyse.

# %%
# !pip install seaborn
import seaborn as sns

# !pip install pymongo
from pymongo import MongoClient
import pandas as pd
# !pip install matplotlib

import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: seaborn in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from seaborn) (1.24.4)
# Requirement already satisfied: pandas>=1.2 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from seaborn) (2.0.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from seaborn) (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (6.4.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: zipp>=3.1.0 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.20.2)
# Requirement already satisfied: six>=1.5 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Requirement already satisfied: pymongo in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (4.10.1)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from pymongo) (2.6.1)
# Requirement already satisfied: matplotlib in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (3.7.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy<2,>=1.20 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.2)
# Requirement already satisfied: six>=1.5 in /Users/juliabrandstatter/opt/anaconda3/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
client = MongoClient("mongodb://localhost:27017/")
db = client["lebensmittel"]

# %% [markdown]
# Jeder Datensatz wird einem Supermarkt zugewiesen – basierend auf seiner Quelle oder Collection (z. B. Billa, Hofer, Spar).
# Nur so kann ein sauberer Vergleich erfolgen.

# %%
client = MongoClient("mongodb://localhost:27017/")
db = client["lebensmittel"]
collection = db["produkte"]

hofer = pd.DataFrame(list(db["hofer"].find()))
billa = pd.DataFrame(list(db["billa"].find()))
spar = pd.DataFrame(list(db["spar"].find()))

hofer["Supermarkt"] = "Hofer"
billa["Supermarkt"] = "Billa"
spar["Supermarkt"] = "Spar"

df = pd.concat([hofer, billa, spar], ignore_index=True)
df = df[["Produkt", "Preis", "Supermarkt"]]

# %% [markdown]
# Die Preisspalte enthält Formatierungen wie `€` und Kommas.
# Wir bereinigen diese Angaben und wandeln sie in **numerische Werte** (Floats) um, um sie für Berechnungen und Visualisierungen zu nutzen.

# %%
df["Preis"] = (
    df["Preis"]
    .astype(str)
    .str.replace("€", "", regex=False)
    .str.replace(",", ".", regex=False)
    .str.replace(r"[^\d.]", "", regex=True)
    .str.strip()
)
df["Preis"] = pd.to_numeric(df["Preis"], errors="coerce")
df = df[df["Preis"].notna()]

# %%
print(df.columns)
# Out:
# Index(['Produkt', 'Preis', 'Supermarkt'], dtype='object')

# %%
avg_prices = df.groupby("Supermarkt")["Preis"].mean()

plt.figure(figsize=(8, 5))
plt.bar(avg_prices.index, avg_prices.values, color="skyblue")
plt.title("Durchschnittlicher Produktpreis pro Supermarkt")
plt.ylabel("Preis in €")
plt.xlabel("Supermarkt")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
colors = ["#2E86C1", "#28B463", "#F4D03F"]
plt.bar(avg_prices.index, avg_prices.values, color=colors)
plt.show()

# %% [markdown]
# Ein **Balkendiagramm** zeigt den **durchschnittlichen Preis pro Supermarkt**.
# So lässt sich auf einen Blick erkennen, welcher Markt im Schnitt am günstigsten oder teuersten ist.

# %%
anzahl_produkte = df["Supermarkt"].value_counts()

plt.figure(figsize=(6, 6))
plt.pie(
    anzahl_produkte.values,
    labels=anzahl_produkte.index,
    autopct="%1.1f%%",
    startangle=140
)
plt.title("Produktverteilung nach Supermarkt")
plt.axis("equal")  # Kreis statt Oval
plt.tight_layout()
plt.show()

# %% [markdown]
# In einem **Kreisdiagramm** visualisieren wir, wie viele Produkte aus welchem Supermarkt in unseren Daten vertreten sind.
# Das zeigt mögliche **Datenungleichgewichte** oder die Produktvielfalt je Anbieter.

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x="Supermarkt", y="Preis", data=df, palette="Set2")

# Plot-Details
plt.title("Preisverteilung pro Supermarkt (Boxplot)")
plt.xlabel("Supermarkt")
plt.ylabel("Preis in €")
plt.grid(axis="y", linestyle="--", alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# /var/folders/0n/l59sm1pn7q57883vnyl3qkkm0000gn/T/ipykernel_12218/2775743083.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Supermarkt", y="Preis", data=df, palette="Set2")

# %% [markdown]
# Ein **Boxplot** stellt die Preisstreuung dar – also wie stark die Preise innerhalb eines Supermarkts schwanken.
# Er zeigt auch Ausreißer und gibt ein Gefühl für die Preisstruktur.

# %% [markdown]
# Wir konnten mit Hilfe von Python, MongoDB, `pandas` und `matplotlib` Preisunterschiede erkennen und visualisieren.
# Alle drei Märkte unterscheiden sich in Verteilung und Durchschnittspreisen – besonders interessant für datenbasierte Konsumentenvergleiche.
