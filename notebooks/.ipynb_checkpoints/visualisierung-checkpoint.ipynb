# %% [markdown]
# In diesem Notebook visualisieren wir Produktpreise aus Hofer-Daten, die im Rahmen des Projekts gescraped wurden. Ziel ist es, auffällige Preisstrukturen sichtbar zu machen.

# %%
import pandas as pd
# !pip install matplotlib

import matplotlib.pyplot as plt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 33.3 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 40.6 MB/s eta 0:00:00
# ...

# %%
hofer = pd.read_csv("../data/hofer_kategorien.csv")
billa = pd.read_csv("../data/billa_mehrere_seiten.csv")
spar = pd.read_csv("../data/interspar_kategorien.csv")

# %%
def clean_preise(df):
    df["Preis"] = df["Preis"].astype(str)
    df["Preis"] = df["Preis"].str.replace("€", "", regex=True)
    df["Preis"] = df["Preis"].str.replace(",", ".", regex=False)
    df["Preis"] = df["Preis"].str.strip()
    return df.astype({"Preis": float})

# %%
hofer = clean_preise(hofer)
billa = clean_preise(billa)
spar = clean_preise(spar)

# %%
avg_prices = {
    "Hofer": hofer["Preis"].mean(),
    "Billa": billa["Preis"].mean(),
    "Spar": spar["Preis"].mean()
}

plt.figure(figsize=(8, 5))
plt.bar(avg_prices.keys(), avg_prices.values(), color="skyblue")
plt.title("Durchschnittlicher Produktpreis pro Supermarkt")
plt.ylabel("Preis in €")
plt.xlabel("Supermarkt")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# Dieses Balkendiagramm vergleicht die durchschnittlichen Preise der Supermärkte. Hofer ist im Schnitt günstiger.

# %%
anzahl_produkte = {
    "Hofer": len(hofer),
    "Billa": len(billa),
    "Spar": len(spar)
}

plt.figure(figsize=(6, 6))
plt.pie(anzahl_produkte.values(), labels=anzahl_produkte.keys(), autopct="%1.1f%%", startangle=140)
plt.title("Produktverteilung nach Supermarkt")
plt.axis("equal")
plt.tight_layout()
plt.show()

# %% [markdown]
# Dieses Diagramm zeigt, wie groß das Sortiment je Markt ist. Billa und Spar bieten tendenziell mehr Produkte.

# %%
plt.figure(figsize=(10, 6))
plt.hist(hofer["Preis"], bins=10, alpha=0.5, label="Hofer", color='mediumseagreen')
plt.hist(billa["Preis"], bins=10, alpha=0.5, label="Billa", color='orange')
plt.hist(spar["Preis"], bins=10, alpha=0.5, label="Spar", color='crimson')
plt.title("Preisverteilung nach Supermarkt")
plt.xlabel("Preis (€)")
plt.ylabel("Anzahl Produkte")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# Dieses Histogramm zeigt, wie sich die Produkte in verschiedene Preisspannen verteilen. Hofer bietet mehr günstige Produkte unter 2 €, während Spar häufiger im mittleren bis höheren Preissegment liegt.
